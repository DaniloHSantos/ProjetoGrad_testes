# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
def Shuffle_Arrays(a,b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]

# %% [markdown]
# Total das imagens
#  - Circulo: 200
#  - Coroa: 200
#  - Setas(Cada direção): 200
#
# Proporção:
#  - Circulo: 140/60
#  - Coroa: 140/60
#  - Setas: 140/60

# %% [markdown]
# ### Labels:
#
#  - Circulo = 0
#  - Coroa = 1
#  - Seta Baixo = 2
#  - Seta Cima = 3
#  - Seta Direita = 4
#  - Seta Esquerda = 5

# %% [markdown]
# # BOLD

# %%
main_path = os.getcwd()

#70% das imagens
ImagesArrayTrain = np.empty((0,28,28))
ImagesArrayTest = np.empty((0,28,28))

#30% das imagens
LabelArrayTrain = np.empty((0))
LabelArrayTest = np.empty((0))

#=================== BOLD ===================

#Circulo Bold

#Cria os arrays
ImagesArray0 = []
LabelArray0 = []
CirculoBoldPath = os.path.join(main_path,"BalancedDataBase\\Bold\\Circulo")
LabelNumber = 0

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(CirculoBoldPath):
    imgPath = os.path.join(CirculoBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray0.append(imgLoad)
    LabelArray0.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray0)
print(np.shape(ImagesArray0))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray0[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray0[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray0[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray0[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Coroa Bold

#Cria os arrays
ImagesArray1 = []
LabelArray1 = []
CoroaBoldPath = os.path.join(main_path,"BalancedDataBase\\Bold\\Coroa")
LabelNumber = 1

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(CoroaBoldPath):
    imgPath = os.path.join(CoroaBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray1.append(imgLoad)
    LabelArray1.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray1)
print(np.shape(ImagesArray1))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray1[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray1[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray1[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray1[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Seta Baixo Bold

#Cria os arrays
ImagesArray2 = []
LabelArray2 = []
SetaBaixoBoldPath = os.path.join(main_path,"BalancedDataBase\\Bold\\SetaBaixo")
LabelNumber = 2

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaBaixoBoldPath):
    imgPath = os.path.join(SetaBaixoBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray2.append(imgLoad)
    LabelArray2.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray2)
print(np.shape(ImagesArray2))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray2[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray2[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray2[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray2[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Seta Cima Bold

#Cria os arrays
ImagesArray3 = []
LabelArray3 = []
SetaCimaBoldPath = os.path.join(main_path,"BalancedDataBase\\Bold\\SetaCima")
LabelNumber = 3

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaCimaBoldPath):
    imgPath = os.path.join(SetaCimaBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray3.append(imgLoad)
    LabelArray3.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray3)
print(np.shape(ImagesArray3))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray3[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray3[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray3[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray3[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Seta Direita Bold

#Cria os arrays
ImagesArray4 = []
LabelArray4 = []
SetaDireitaBoldPath = os.path.join(main_path,"BalancedDataBase\\Bold\\SetaDireita")
LabelNumber = 4

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaDireitaBoldPath):
    imgPath = os.path.join(SetaDireitaBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray4.append(imgLoad)
    LabelArray4.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray4)
print(np.shape(ImagesArray4))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray4[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray4[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray4[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray4[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Seta Esquerda Bold

#Cria os arrays
ImagesArray5 = []
LabelArray5 = []
SetaEsquerdaBoldPath = os.path.join(main_path,"BalancedDataBase\\Bold\\SetaEsquerda")
LabelNumber = 5

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaEsquerdaBoldPath):
    imgPath = os.path.join(SetaEsquerdaBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray5.append(imgLoad)
    LabelArray5.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray5)
print(np.shape(ImagesArray5))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray5[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray5[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray5[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray5[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Array final
ImagensArrayTrainFinal, LabelArrayTrainFinal = Shuffle_Arrays(ImagesArrayTrain,LabelArrayTrain)
ImagensArrayTestFinal, LabelArrayTestFinal = Shuffle_Arrays(ImagesArrayTest,LabelArrayTest)

BoldTrainData = ImagensArrayTrainFinal, LabelArrayTrainFinal
BoldTestData = ImagensArrayTestFinal, LabelArrayTestFinal
# Out:
# (200, 28, 28)
# (140, 28, 28)
# (60, 28, 28)
# (140,)
# (60,)
# (200, 28, 28)
# (280, 28, 28)
# (120, 28, 28)
# (280,)
# (120,)
# (200, 28, 28)
# (420, 28, 28)
# (180, 28, 28)
# (420,)
# (180,)
# (200, 28, 28)
# (560, 28, 28)
# (240, 28, 28)
# (560,)
# (240,)
# (200, 28, 28)
# (700, 28, 28)
# (300, 28, 28)
# (700,)
# (300,)
# (200, 28, 28)
# (840, 28, 28)
# (360, 28, 28)
# (840,)
# (360,)

# %%
np.save("SavedDataBase\\Bold\\BoldTrainDataImages",ImagensArrayTrainFinal)
np.save("SavedDataBase\\Bold\\BoldTrainDataLables",LabelArrayTrainFinal)
np.save("SavedDataBase\\Bold\\BoldTestDataImages",ImagensArrayTestFinal)
np.save("SavedDataBase\\Bold\\BoldTestDataLables",LabelArrayTestFinal)

# %%
test = np.load("SavedDataBase\\Bold\\BoldTrainDataLables.npy")
test
# Out:
# array([1., 2., 3., 5., 5., 5., 0., 2., 5., 4., 2., 2., 0., 0., 0., 2., 4.,
#        4., 0., 1., 2., 0., 3., 4., 1., 4., 5., 1., 3., 2., 4., 1., 1., 3.,
#        0., 3., 2., 0., 5., 1., 0., 3., 3., 3., 0., 2., 0., 2., 2., 3., 1.,
#        0., 5., 3., 5., 2., 4., 1., 2., 3., 4., 1., 0., 0., 0., 5., 0., 1.,
#        5., 2., 0., 4., 4., 2., 1., 3., 4., 5., 1., 3., 3., 2., 4., 3., 0.,
#        1., 1., 2., 1., 4., 3., 5., 3., 0., 2., 4., 0., 2., 0., 5., 5., 3.,
#        0., 0., 4., 1., 3., 2., 2., 0., 1., 0., 5., 4., 4., 4., 0., 1., 1.,
#        4., 3., 3., 1., 3., 4., 2., 4., 0., 2., 4., 1., 4., 4., 2., 3., 3.,
#        4., 2., 4., 5., 0., 3., 2., 0., 5., 3., 1., 2., 2., 4., 0., 1., 5.,
#        4., 5., 0., 1., 5., 0., 0., 3., 2., 3., 0., 2., 1., 3., 2., 2., 3.,
#        5., 2., 3., 0., 3., 1., 4., 5., 1., 3., 3., 0., 0., 3., 3., 0., 3.,
#        0., 4., 0., 2., 5., 0., 3., 0., 1., 0., 5., 4., 5., 2., 2., 1., 2.,
#        0., 4., 1., 0., 4., 1., 3., 2., 3., 5., 3., 5., 3., 5., 5., 3., 1.,
#        5., 0., 0., 1., 1., 3., 5., 3., 2., 0., 0., 0., 4., 4., 0., 1., 1.,
#        5., 3., 1., 3., 2., 1., 4., 1., 5., 4., 5., 3., 0., 3., 0., 5., 2.,
#        3., 4., 5., 2., 1., 0., 1., 2., 4., 1., 4., 3., 4., 1., 3., 5., 3.,
#        4., 2., 0., 5., 3., 4., 0., 4., 0., 5., 4., 3., 4., 5., 0., 1., 0.,
#        3., 1., 0., 3., 5., 1., 4., 0., 1., 2., 3., 5., 4., 0., 1., 1., 5.,
#        0., 3., 3., 2., 2., 0., 0., 1., 0., 1., 3., 1., 5., 3., 4., 2., 1.,
#        4., 3., 3., 5., 3., 1., 1., 0., 3., 0., 1., 1., 3., 5., 0., 1., 3.,
#        4., 3., 5., 5., 2., 3., 5., 5., 4., 0., 3., 5., 1., 0., 5., 4., 3.,
#        2., 5., 0., 0., 1., 2., 2., 5., 2., 2., 4., 3., 5., 4., 3., 1., 2.,
#        0., 4., 2., 1., 2., 0., 1., 4., 2., 1., 4., 5., 1., 5., 1., 1., 5.,
#        3., 0., 1., 5., 4., 3., 1., 1., 4., 1., 1., 5., 5., 4., 2., 2., 3.,
#        1., 5., 1., 3., 5., 2., 5., 1., 2., 4., 0., 0., 5., 3., 0., 1., 1.,
#        3., 0., 0., 3., 1., 1., 0., 4., 2., 1., 2., 5., 2., 2., 4., 2., 2.,
#        0., 1., 5., 5., 4., 2., 0., 4., 2., 5., 2., 1., 3., 2., 2., 4., 1.,
#        0., 3., 0., 1., 0., 2., 2., 2., 3., 5., 5., 4., 3., 0., 3., 5., 0.,
#        3., 4., 1., 0., 4., 1., 4., 0., 3., 0., 5., 1., 1., 2., 0., 5., 4.,
#        5., 5., 0., 3., 3., 2., 4., 4., 0., 4., 1., 3., 3., 4., 5., 0., 0.,
#        1., 4., 1., 0., 4., 3., 2., 1., 0., 4., 5., 1., 1., 2., 5., 2., 1.,
#        4., 0., 3., 3., 0., 2., 5., 4., 5., 2., 5., 4., 4., 5., 0., 3., 2.,
#        0., 0., 1., 2., 4., 5., 1., 5., 3., 2., 4., 1., 5., 2., 2., 2., 3.,
#        1., 5., 4., 4., 5., 3., 4., 2., 5., 2., 4., 1., 1., 3., 4., 4., 5.,
#        1., 5., 2., 1., 3., 3., 1., 2., 2., 0., 2., 3., 2., 5., 5., 3., 5.,
#        4., 5., 2., 0., 0., 2., 4., 0., 0., 1., 1., 3., 4., 3., 5., 2., 5.,
#        5., 3., 3., 3., 4., 2., 5., 5., 4., 0., 0., 2., 2., 4., 4., 5., 5.,
#        2., 1., 3., 2., 0., 0., 2., 5., 2., 3., 5., 2., 5., 0., 4., 5., 3.,
#        1., 0., 1., 2., 4., 0., 1., 1., 4., 2., 1., 2., 0., 5., 0., 1., 0.,
#        0., 3., 2., 1., 4., 3., 1., 3., 4., 2., 4., 3., 0., 3., 3., 5., 1.,
#        1., 4., 1., 2., 4., 4., 3., 4., 4., 0., 4., 1., 2., 5., 0., 0., 3.,
#        5., 5., 4., 4., 4., 2., 1., 1., 0., 3., 5., 2., 5., 3., 3., 1., 4.,
#        5., 4., 1., 2., 4., 0., 0., 4., 1., 2., 3., 0., 1., 5., 4., 5., 3.,
#        5., 5., 4., 5., 0., 3., 3., 5., 5., 2., 1., 5., 5., 2., 4., 5., 4.,
#        2., 4., 5., 4., 0., 0., 0., 0., 0., 5., 3., 2., 5., 2., 1., 2., 4.,
#        1., 3., 5., 3., 2., 3., 4., 5., 3., 2., 5., 5., 5., 3., 3., 3., 4.,
#        1., 0., 2., 2., 5., 4., 1., 4., 5., 4., 2., 4., 2., 0., 4., 0., 2.,
#        4., 5., 5., 2., 4., 4., 2., 0., 1., 4., 2., 1., 0., 3., 1., 2., 2.,
#        1., 4., 5., 4., 4., 2., 4., 1., 3., 3., 2., 1., 1., 4., 2., 3., 5.,
#        5., 5., 0., 1., 2., 3., 1.])

# %%
fig, ax = plt.subplots(10,4,figsize=(10,15))
for i in range(40):
    plt.subplot(10,4,i+1)
    plt.imshow(ImagensArrayTestFinal[i])
    plt.title(LabelArrayTestFinal[i])
fig.tight_layout()
plt.show()

# %% [markdown]
# # Thin

# %%
main_path = os.getcwd()

#70% das imagens
ImagesArrayTrain = np.empty((0,28,28))
ImagesArrayTest = np.empty((0,28,28))

#30% das imagens
LabelArrayTrain = np.empty((0))
LabelArrayTest = np.empty((0))

#=================== Thin ===================

#Circulo Thin

#Cria os arrays
ImagesArray0 = []
LabelArray0 = []
CirculoThinPath = os.path.join(main_path,"BalancedDataBase\\Thin\\Circulo")
LabelNumber = 0

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(CirculoThinPath):
    imgPath = os.path.join(CirculoThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray0.append(imgLoad)
    LabelArray0.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray0)
print(np.shape(ImagesArray0))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray0[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray0[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray0[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray0[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Coroa Thin

#Cria os arrays
ImagesArray1 = []
LabelArray1 = []
CoroaThinPath = os.path.join(main_path,"BalancedDataBase\\Thin\\Coroa")
LabelNumber = 1

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(CoroaThinPath):
    imgPath = os.path.join(CoroaThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray1.append(imgLoad)
    LabelArray1.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray1)
print(np.shape(ImagesArray1))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray1[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray1[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray1[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray1[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Seta Baixo Thin

#Cria os arrays
ImagesArray2 = []
LabelArray2 = []
SetaBaixoThinPath = os.path.join(main_path,"BalancedDataBase\\Thin\\SetaBaixo")
LabelNumber = 2

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaBaixoThinPath):
    imgPath = os.path.join(SetaBaixoThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray2.append(imgLoad)
    LabelArray2.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray2)
print(np.shape(ImagesArray2))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray2[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray2[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray2[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray2[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Seta Cima Thin

#Cria os arrays
ImagesArray3 = []
LabelArray3 = []
SetaCimaThinPath = os.path.join(main_path,"BalancedDataBase\\Thin\\SetaCima")
LabelNumber = 3

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaCimaThinPath):
    imgPath = os.path.join(SetaCimaThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray3.append(imgLoad)
    LabelArray3.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray3)
print(np.shape(ImagesArray3))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray3[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray3[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray3[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray3[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Seta Direita Thin

#Cria os arrays
ImagesArray4 = []
LabelArray4 = []
SetaDireitaThinPath = os.path.join(main_path,"BalancedDataBase\\Thin\\SetaDireita")
LabelNumber = 4

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaDireitaThinPath):
    imgPath = os.path.join(SetaDireitaThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray4.append(imgLoad)
    LabelArray4.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray4)
print(np.shape(ImagesArray4))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray4[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray4[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray4[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray4[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Seta Esquerda Thin

#Cria os arrays
ImagesArray5 = []
LabelArray5 = []
SetaEsquerdaThinPath = os.path.join(main_path,"BalancedDataBase\\Thin\\SetaEsquerda")
LabelNumber = 5

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaEsquerdaThinPath):
    imgPath = os.path.join(SetaEsquerdaThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray5.append(imgLoad)
    LabelArray5.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray5)
print(np.shape(ImagesArray5))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray5[:140]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray5[140:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray5[:140]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray5[140:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#=================================================================================

#Array final
ImagensArrayTrainFinal, LabelArrayTrainFinal = Shuffle_Arrays(ImagesArrayTrain,LabelArrayTrain)
ImagensArrayTestFinal, LabelArrayTestFinal = Shuffle_Arrays(ImagesArrayTest,LabelArrayTest)

ThinTrainData = ImagensArrayTrainFinal, LabelArrayTrainFinal
ThinTestData = ImagensArrayTestFinal, LabelArrayTestFinal
# Out:
# (200, 28, 28)
# (140, 28, 28)
# (60, 28, 28)
# (140,)
# (60,)
# (200, 28, 28)
# (280, 28, 28)
# (120, 28, 28)
# (280,)
# (120,)
# (200, 28, 28)
# (420, 28, 28)
# (180, 28, 28)
# (420,)
# (180,)
# (200, 28, 28)
# (560, 28, 28)
# (240, 28, 28)
# (560,)
# (240,)
# (200, 28, 28)
# (700, 28, 28)
# (300, 28, 28)
# (700,)
# (300,)
# (200, 28, 28)
# (840, 28, 28)
# (360, 28, 28)
# (840,)
# (360,)

# %%
np.save("SavedDataBase\\Thin\\ThinTrainDataImages",ImagensArrayTrainFinal)
np.save("SavedDataBase\\Thin\\ThinTrainDataLables",LabelArrayTrainFinal)
np.save("SavedDataBase\\Thin\\ThinTestDataImages",ImagensArrayTestFinal)
np.save("SavedDataBase\\Thin\\ThinTestDataLables",LabelArrayTestFinal)

# %%
test = np.load("SavedDataBase\\Thin\\ThinTrainDataLables.npy")
test
# Out:
# array([0., 0., 2., 2., 2., 0., 4., 4., 1., 5., 4., 5., 0., 2., 5., 3., 1.,
#        1., 3., 5., 3., 3., 1., 5., 3., 0., 0., 2., 3., 0., 0., 1., 0., 1.,
#        4., 3., 0., 4., 5., 1., 1., 1., 0., 2., 3., 1., 2., 2., 5., 1., 2.,
#        5., 4., 0., 4., 3., 0., 5., 3., 1., 0., 0., 1., 4., 2., 2., 0., 3.,
#        1., 4., 2., 1., 3., 1., 3., 0., 4., 4., 4., 5., 2., 4., 4., 2., 0.,
#        2., 1., 3., 4., 0., 2., 4., 5., 5., 0., 1., 4., 1., 5., 0., 5., 0.,
#        5., 2., 0., 3., 3., 5., 3., 3., 2., 3., 4., 0., 4., 2., 5., 2., 5.,
#        5., 3., 4., 5., 4., 2., 1., 0., 1., 1., 0., 4., 5., 5., 3., 1., 0.,
#        2., 3., 4., 3., 1., 0., 0., 3., 2., 0., 3., 0., 5., 5., 4., 4., 0.,
#        1., 0., 1., 2., 2., 1., 4., 2., 2., 4., 3., 3., 2., 5., 5., 0., 1.,
#        3., 2., 3., 4., 5., 0., 4., 5., 4., 3., 5., 5., 4., 3., 3., 2., 1.,
#        1., 1., 5., 4., 0., 3., 4., 5., 0., 5., 2., 2., 5., 4., 0., 4., 0.,
#        1., 1., 3., 0., 5., 5., 0., 0., 5., 2., 3., 5., 3., 5., 2., 4., 3.,
#        2., 0., 2., 2., 2., 5., 5., 0., 1., 4., 0., 1., 5., 4., 5., 4., 4.,
#        1., 2., 1., 4., 4., 2., 2., 3., 2., 1., 5., 3., 2., 5., 5., 4., 0.,
#        4., 0., 1., 3., 2., 5., 5., 4., 1., 3., 0., 1., 5., 0., 0., 0., 3.,
#        4., 5., 3., 5., 3., 4., 0., 4., 2., 5., 5., 0., 1., 1., 2., 2., 3.,
#        1., 4., 2., 2., 4., 4., 3., 0., 4., 3., 2., 0., 5., 5., 3., 1., 2.,
#        4., 3., 3., 1., 0., 2., 2., 5., 3., 1., 2., 3., 1., 3., 0., 5., 3.,
#        2., 4., 5., 1., 1., 5., 0., 2., 0., 3., 1., 0., 2., 5., 0., 3., 2.,
#        2., 1., 4., 5., 0., 4., 5., 1., 3., 2., 5., 3., 4., 2., 0., 3., 0.,
#        3., 1., 5., 5., 1., 1., 3., 3., 5., 5., 5., 1., 1., 3., 1., 5., 0.,
#        1., 5., 4., 0., 5., 0., 2., 5., 2., 3., 5., 1., 1., 2., 4., 4., 2.,
#        4., 3., 2., 0., 5., 5., 2., 3., 5., 1., 0., 4., 3., 3., 1., 1., 1.,
#        0., 5., 0., 1., 2., 2., 2., 4., 0., 3., 5., 0., 4., 1., 1., 0., 0.,
#        4., 2., 3., 3., 3., 1., 0., 3., 2., 2., 2., 5., 4., 4., 4., 5., 5.,
#        3., 4., 1., 2., 2., 1., 3., 2., 2., 0., 0., 2., 0., 4., 2., 0., 0.,
#        2., 4., 1., 3., 4., 0., 2., 5., 4., 5., 1., 0., 5., 3., 4., 0., 1.,
#        5., 2., 1., 0., 0., 5., 3., 0., 2., 3., 4., 5., 3., 2., 0., 4., 3.,
#        5., 4., 3., 1., 0., 3., 0., 1., 2., 0., 0., 0., 4., 2., 1., 1., 5.,
#        4., 2., 1., 3., 5., 3., 5., 0., 4., 5., 5., 1., 2., 5., 1., 1., 2.,
#        5., 3., 3., 3., 4., 4., 3., 2., 5., 1., 0., 3., 1., 0., 2., 0., 4.,
#        5., 5., 2., 3., 2., 1., 3., 1., 1., 2., 2., 3., 3., 1., 5., 5., 1.,
#        2., 2., 3., 1., 0., 2., 5., 3., 0., 5., 4., 0., 3., 4., 4., 2., 3.,
#        3., 1., 0., 1., 0., 2., 3., 2., 3., 2., 1., 5., 1., 3., 2., 3., 4.,
#        1., 0., 0., 5., 3., 4., 1., 5., 1., 4., 2., 0., 4., 2., 1., 2., 3.,
#        4., 3., 1., 1., 2., 0., 2., 4., 2., 5., 5., 5., 4., 5., 1., 5., 0.,
#        0., 4., 2., 5., 0., 4., 1., 4., 4., 1., 1., 3., 4., 0., 4., 0., 5.,
#        3., 5., 1., 3., 4., 0., 5., 1., 2., 0., 5., 3., 2., 2., 0., 4., 3.,
#        4., 1., 1., 5., 5., 0., 3., 5., 2., 3., 1., 1., 3., 3., 4., 1., 3.,
#        2., 4., 2., 5., 1., 3., 3., 2., 2., 2., 4., 3., 5., 1., 3., 2., 2.,
#        4., 4., 4., 3., 4., 1., 3., 4., 3., 4., 5., 2., 3., 0., 1., 4., 5.,
#        4., 3., 4., 5., 5., 3., 5., 0., 3., 1., 5., 4., 4., 2., 4., 4., 4.,
#        0., 1., 2., 4., 0., 5., 2., 5., 4., 5., 3., 4., 0., 4., 5., 1., 0.,
#        3., 0., 0., 1., 3., 1., 5., 4., 3., 2., 0., 2., 0., 4., 4., 4., 0.,
#        4., 4., 5., 1., 5., 2., 2., 0., 3., 4., 4., 1., 1., 0., 3., 5., 5.,
#        0., 2., 5., 2., 4., 5., 1., 0., 1., 1., 0., 3., 0., 0., 1., 5., 3.,
#        0., 3., 2., 1., 4., 1., 1., 2., 3., 0., 4., 3., 2., 2., 1., 4., 4.,
#        3., 0., 1., 5., 4., 3., 1., 1., 0., 4., 0., 2., 1., 5., 4., 4., 1.,
#        2., 1., 1., 0., 2., 0., 2.])

# %%
fig, ax = plt.subplots(10,4,figsize=(10,15))
for i in range(40):
    plt.subplot(10,4,i+1)
    plt.imshow(ImagensArrayTestFinal[i])
    plt.title(LabelArrayTestFinal[i])
fig.tight_layout()
plt.show()
