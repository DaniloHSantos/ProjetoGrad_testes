# %%
y=0
for i in range(300):
    if i % 3 == 0:
        y += 1
        print(i+1)
print(f'y = {y}')
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# 22
# 25
# 28
# 31
# 34
# 37
# 40
# 43
# 46
# 49
# 52
# 55
# 58
# 61
# 64
# 67
# 70
# 73
# 76
# 79
# 82
# 85
# 88
# 91
# 94
# 97
# 100
# 103
# 106
# 109
# 112
# 115
# 118
# 121
# 124
# 127
# 130
# 133
# 136
# 139
# 142
# 145
# 148
# 151
# 154
# 157
# 160
# 163
# 166
# 169
# 172
# 175
# 178
# 181
# 184
# 187
# 190
# 193
# 196
# 199
# 202
# 205
# 208
# 211
# 214
# 217
# 220
# 223
# 226
# 229
# 232
# 235
# 238
# 241
# 244
# 247
# 250
# 253
# 256
# 259
# 262
# 265
# 268
# 271
# 274
# 277
# 280
# 283
# 286
# 289
# 292
# 295
# 298
# y = 100

# %%
import os

main_path = os.getcwd()
pathSetaBaixoThin = os.path.join(main_path, "DataBaseSetas1\\Thin\\SetaBaixo")
pathSetaBaixoBold = os.path.join(main_path, "DataBaseSetas1\\Bold\\SetaBaixo")
NomeSetaBaixoThin = "SetaBaixo-Thin-"
NomeSetaBaixoBold = "SetaBaixo-Bold-"

for i in range(750):
    if i % 3 == 0:
        print(i+1)
        path1 = os.path.join(pathSetaBaixoThin, NomeSetaBaixoThin + str(i+1) + ".jpg")
        path2 = os.path.join(pathSetaBaixoBold, NomeSetaBaixoBold + str(i+1) + ".jpg")
        if os.path.exists(path1):
            os.remove(path1)
        if os.path.exists(path2):
            os.remove(path2)

pathSetaCimaThin = os.path.join(main_path, "DataBaseSetas1\\Thin\\SetaCima")
pathSetaCimaBold = os.path.join(main_path, "DataBaseSetas1\\Bold\\SetaCima")
NomeSetaCimaThin = "SetaCima-Thin-"
NomeSetaCimaBold = "SetaCima-Bold-"

for i in range(750):
    if i % 3 == 0:
        print(i+1)
        path1 = os.path.join(pathSetaCimaThin, NomeSetaCimaThin + str(i+1) + ".jpg")
        path2 = os.path.join(pathSetaCimaBold, NomeSetaCimaBold + str(i+1) + ".jpg")
        if os.path.exists(path1):
            os.remove(path1)
        if os.path.exists(path2):
            os.remove(path2)

pathSetaDireitaThin = os.path.join(main_path, "DataBaseSetas1\\Thin\\SetaDireita")
pathSetaDireitaBold = os.path.join(main_path, "DataBaseSetas1\\Bold\\SetaDireita")
NomeSetaDireitaThin = "SetaDireita-Thin-"
NomeSetaDireitaBold = "SetaDireita-Bold-"

for i in range(750):
    if i % 3 == 0:
        print(i+1)
        path1 = os.path.join(pathSetaDireitaThin, NomeSetaDireitaThin + str(i+1) + ".jpg")
        path2 = os.path.join(pathSetaDireitaBold, NomeSetaDireitaBold + str(i+1) + ".jpg")
        if os.path.exists(path1):
            os.remove(path1)
        if os.path.exists(path2):
            os.remove(path2)

pathSetaEsquerdaThin = os.path.join(main_path, "DataBaseSetas1\\Thin\\SetaEsquerda")
pathSetaEsquerdaBold = os.path.join(main_path, "DataBaseSetas1\\Bold\\SetaEsquerda")
NomeSetaEsquerdaThin = "SetaEsquerda-Thin-"
NomeSetaEsquerdaBold = "SetaEsquerda-Bold-"

for i in range(750):
    if i % 3 == 0:
        print(i+1)
        path1 = os.path.join(pathSetaEsquerdaThin, NomeSetaEsquerdaThin + str(i+1) + ".jpg")
        path2 = os.path.join(pathSetaEsquerdaBold, NomeSetaEsquerdaBold + str(i+1) + ".jpg")
        if os.path.exists(path1):
            os.remove(path1)
        if os.path.exists(path2):
            os.remove(path2)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# 22
# 25
# 28
# 31
# 34
# 37
# 40
# 43
# 46
# 49
# 52
# 55
# 58
# 61
# 64
# 67
# 70
# 73
# 76
# 79
# 82
# 85
# 88
# 91
# 94
# 97
# 100
# 103
# 106
# 109
# 112
# 115
# 118
# 121
# 124
# 127
# 130
# 133
# 136
# 139
# 142
# 145
# 148
# 151
# 154
# 157
# 160
# 163
# 166
# 169
# 172
# 175
# 178
# 181
# 184
# 187
# 190
# 193
# 196
# 199
# 202
# 205
# 208
# 211
# 214
# 217
# 220
# 223
# 226
# 229
# 232
# 235
# 238
# 241
# 244
# 247
# 250
# 253
# 256
# 259
# 262
# 265
# 268
# 271
# 274
# 277
# 280
# 283
# 286
# 289
# 292
# 295
# 298
# 301
# 304
# 307
# 310
# 313
# 316
# 319
# 322
# 325
# 328
# 331
# 334
# 337
# 340
# 343
# 346
# 349
# 352
# 355
# 358
# 361
# 364
# 367
# 370
# 373
# 376
# 379
# 382
# 385
# 388
# 391
# 394
# 397
# 400
# 403
# 406
# 409
# 412
# 415
# 418
# 421
# 424
# 427
# 430
# 433
# 436
# 439
# 442
# 445
# 448
# 451
# 454
# 457
# 460
# 463
# 466
# 469
# 472
# 475
# 478
# 481
# 484
# 487
# 490
# 493
# 496
# 499
# 502
# 505
# 508
# 511
# 514
# ...
