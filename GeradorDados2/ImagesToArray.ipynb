# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
def Shuffle_Arrays(a,b):
    assert len(a) == len(b)
    p = np.random.permutation(len(a))
    return a[p], b[p]

# %% [markdown]
# Total das imagens
#  - Circulo: 1400
#  - Coroa: 2450
#  - Setas(Cada direção): 3400
#
# Proporção:
#  - Circulo: 980/420
#  - Coroa: 1715/735
#  - Setas: 2380/1020

# %% [markdown]
# ### Labels:
#
#  - Seta Baixo = 0
#  - Seta Cima = 1
#  - Seta Esquerda = 2
#  - Seta Direita = 3
#  - Circulo = 4
#  - Coroa = 5

# %% [markdown]
# # BOLD

# %%
main_path = os.getcwd()

#70% das imagens
ImagesArrayTrain = np.empty((0,28,28))
ImagesArrayTest = np.empty((0,28,28))

#30% das imagens
LabelArrayTrain = np.empty((0))
LabelArrayTest = np.empty((0))

#=================== BOLD ===================

#Seta Baixo Bold

#Cria os arrays
ImagesArray0 = []
LabelArray0 = []
SetaBaixoBoldPath = os.path.join(main_path,"DataBase\\Bold\\SetaBaixo")
LabelNumber = 0

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaBaixoBoldPath):
    imgPath = os.path.join(SetaBaixoBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray0.append(imgLoad)
    LabelArray0.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray0)
print(np.shape(ImagesArray0))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray0[:2380]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray0[2380:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray0[:2380]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray0[2380:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#Seta Cima Bold

#Cria os arrays
ImagesArray1 = []
LabelArray1 = []
SetaCimaBoldPath = os.path.join(main_path,"DataBase\\Bold\\SetaCima")
LabelNumber = 1

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaCimaBoldPath):
    imgPath = os.path.join(SetaCimaBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray1.append(imgLoad)
    LabelArray1.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray1)
print(np.shape(ImagesArray1))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray1[:2380]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray1[2380:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray1[:2380]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray1[2380:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#Seta Esquerda Bold

#Cria os arrays
ImagesArray2 = []
LabelArray2 = []
SetaEsquerdaBoldPath = os.path.join(main_path,"DataBase\\Bold\\SetaEsquerda")
LabelNumber = 2

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaEsquerdaBoldPath):
    imgPath = os.path.join(SetaEsquerdaBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray2.append(imgLoad)
    LabelArray2.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray2)
print(np.shape(ImagesArray2))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray2[:2380]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray2[2380:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray2[:2380]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray2[2380:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#Seta Direita Bold

#Cria os arrays
ImagesArray3 = []
LabelArray3 = []
SetaDireitaBoldPath = os.path.join(main_path,"DataBase\\Bold\\SetaDireita")
LabelNumber = 3

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaDireitaBoldPath):
    imgPath = os.path.join(SetaDireitaBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray3.append(imgLoad)
    LabelArray3.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray3)
print(np.shape(ImagesArray3))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray3[:2380]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray3[2380:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray3[:2380]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray3[2380:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#Circulo Bold

#Cria os arrays
ImagesArray4 = []
LabelArray4 = []
CirculoBoldPath = os.path.join(main_path,"DataBase\\Bold\\Circulo")
LabelNumber = 4

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(CirculoBoldPath):
    imgPath = os.path.join(CirculoBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray4.append(imgLoad)
    LabelArray4.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray4)
print(np.shape(ImagesArray4))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray4[:980]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray4[980:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray4[:980]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray4[980:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#Coroa Bold

#Cria os arrays
ImagesArray5 = []
LabelArray5 = []
CoroaBoldPath = os.path.join(main_path,"DataBase\\Bold\\Coroa")
LabelNumber = 5

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(CoroaBoldPath):
    imgPath = os.path.join(CoroaBoldPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray5.append(imgLoad)
    LabelArray5.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray5)
print(np.shape(ImagesArray5))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray5[:1715]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray5[1715:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray5[:1715]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray5[1715:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))


#Array final
ImagensArrayTrainFinal, LabelArrayTrainFinal = Shuffle_Arrays(ImagesArrayTrain,LabelArrayTrain)
ImagensArrayTestFinal, LabelArrayTestFinal = Shuffle_Arrays(ImagesArrayTest,LabelArrayTest)

BoldTrainData = ImagensArrayTrainFinal, LabelArrayTrainFinal
BoldTestData = ImagensArrayTestFinal, LabelArrayTestFinal
# Out:
# (3400, 28, 28)
# (2380, 28, 28)
# (1020, 28, 28)
# (2380,)
# (1020,)
# (3400, 28, 28)
# (4760, 28, 28)
# (2040, 28, 28)
# (4760,)
# (2040,)
# (3400, 28, 28)
# (7140, 28, 28)
# (3060, 28, 28)
# (7140,)
# (3060,)
# (3400, 28, 28)
# (9520, 28, 28)
# (4080, 28, 28)
# (9520,)
# (4080,)
# (1400, 28, 28)
# (10500, 28, 28)
# (4500, 28, 28)
# (10500,)
# (4500,)
# (2450, 28, 28)
# (12215, 28, 28)
# (5235, 28, 28)
# (12215,)
# (5235,)

# %%
np.save("BoldTrainDataImages",ImagensArrayTrainFinal)
np.save("BoldTrainDataLables",LabelArrayTrainFinal)
np.save("BoldTestDataImages",ImagensArrayTestFinal)
np.save("BoldTestDataLables",LabelArrayTestFinal)

# %%
test = np.load("BoldTrainDataLables.npy")
test
# Out:
# array([1., 3., 5., ..., 5., 1., 2.], shape=(12215,))

# %%
fig, ax = plt.subplots(10,4,figsize=(10,15))
for i in range(40):
    plt.subplot(10,4,i+1)
    plt.imshow(ImagensArrayTestFinal[i])
    plt.title(LabelArrayTestFinal[i])
fig.tight_layout()
plt.show()

# %% [markdown]
# # Thin

# %%
main_path = os.getcwd()

#70% das imagens
ImagesArrayTrain = np.empty((0,28,28))
ImagesArrayTest = np.empty((0,28,28))

#30% das imagens
LabelArrayTrain = np.empty((0))
LabelArrayTest = np.empty((0))

#=================== Thin ===================

#Seta Baixo Thin

#Cria os arrays
ImagesArray0 = []
LabelArray0 = []
SetaBaixoThinPath = os.path.join(main_path,"DataBase\\Thin\\SetaBaixo")
LabelNumber = 0

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaBaixoThinPath):
    imgPath = os.path.join(SetaBaixoThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray0.append(imgLoad)
    LabelArray0.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray0)
print(np.shape(ImagesArray0))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray0[:2380]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray0[2380:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray0[:2380]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray0[2380:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#Seta Cima Thin

#Cria os arrays
ImagesArray1 = []
LabelArray1 = []
SetaCimaThinPath = os.path.join(main_path,"DataBase\\Thin\\SetaCima")
LabelNumber = 1

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaCimaThinPath):
    imgPath = os.path.join(SetaCimaThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray1.append(imgLoad)
    LabelArray1.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray1)
print(np.shape(ImagesArray1))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray1[:2380]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray1[2380:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray1[:2380]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray1[2380:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#Seta Esquerda Thin

#Cria os arrays
ImagesArray2 = []
LabelArray2 = []
SetaEsquerdaThinPath = os.path.join(main_path,"DataBase\\Thin\\SetaEsquerda")
LabelNumber = 2

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaEsquerdaThinPath):
    imgPath = os.path.join(SetaEsquerdaThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray2.append(imgLoad)
    LabelArray2.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray2)
print(np.shape(ImagesArray2))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray2[:2380]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray2[2380:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray2[:2380]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray2[2380:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#Seta Direita Thin

#Cria os arrays
ImagesArray3 = []
LabelArray3 = []
SetaDireitaThinPath = os.path.join(main_path,"DataBase\\Thin\\SetaDireita")
LabelNumber = 3

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(SetaDireitaThinPath):
    imgPath = os.path.join(SetaDireitaThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray3.append(imgLoad)
    LabelArray3.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray3)
print(np.shape(ImagesArray3))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray3[:2380]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray3[2380:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray3[:2380]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray3[2380:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#Circulo Thin

#Cria os arrays
ImagesArray4 = []
LabelArray4 = []
CirculoThinPath = os.path.join(main_path,"DataBase\\Thin\\Circulo")
LabelNumber = 4

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(CirculoThinPath):
    imgPath = os.path.join(CirculoThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray4.append(imgLoad)
    LabelArray4.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray4)
print(np.shape(ImagesArray4))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray4[:980]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray4[980:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray4[:980]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray4[980:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))

#Coroa Thin

#Cria os arrays
ImagesArray5 = []
LabelArray5 = []
CoroaThinPath = os.path.join(main_path,"DataBase\\Thin\\Coroa")
LabelNumber = 5

#Percorre as imagens, carregando elas no array e preenchendo o vetor de labels
for filename in os.listdir(CoroaThinPath):
    imgPath = os.path.join(CoroaThinPath,filename)
    imgLoad = cv2.imread(imgPath,0)
    ImagesArray5.append(imgLoad)
    LabelArray5.append(LabelNumber)

#Mistura as imagens de maneira aleatória
np.random.shuffle(ImagesArray5)
print(np.shape(ImagesArray5))

ImagesArrayTrain = np.concatenate((ImagesArrayTrain,ImagesArray5[:1715]))
ImagesArrayTest = np.concatenate((ImagesArrayTest,ImagesArray5[1715:]))
LabelArrayTrain = np.concatenate((LabelArrayTrain,LabelArray5[:1715]))
LabelArrayTest = np.concatenate((LabelArrayTest,LabelArray5[1715:]))
print(np.shape(ImagesArrayTrain))
print(np.shape(ImagesArrayTest))
print(np.shape(LabelArrayTrain))
print(np.shape(LabelArrayTest))


#Array final
ImagensArrayTrainFinal, LabelArrayTrainFinal = Shuffle_Arrays(ImagesArrayTrain,LabelArrayTrain)
ImagensArrayTestFinal, LabelArrayTestFinal = Shuffle_Arrays(ImagesArrayTest,LabelArrayTest)

ThinTrainData = ImagensArrayTrainFinal, LabelArrayTrainFinal
ThinTestData = ImagensArrayTestFinal, LabelArrayTestFinal
# Out:
# (3400, 28, 28)
# (2380, 28, 28)
# (1020, 28, 28)
# (2380,)
# (1020,)
# (3400, 28, 28)
# (4760, 28, 28)
# (2040, 28, 28)
# (4760,)
# (2040,)
# (3400, 28, 28)
# (7140, 28, 28)
# (3060, 28, 28)
# (7140,)
# (3060,)
# (3400, 28, 28)
# (9520, 28, 28)
# (4080, 28, 28)
# (9520,)
# (4080,)
# (1400, 28, 28)
# (10500, 28, 28)
# (4500, 28, 28)
# (10500,)
# (4500,)
# (2450, 28, 28)
# (12215, 28, 28)
# (5235, 28, 28)
# (12215,)
# (5235,)

# %%
np.save("ThinTrainDataImages",ImagensArrayTrainFinal)
np.save("ThinTrainDataLables",LabelArrayTrainFinal)
np.save("ThinTestDataImages",ImagensArrayTestFinal)
np.save("ThinTestDataLables",LabelArrayTestFinal)

# %%
test = np.load("ThinTrainDataLables.npy")
test
# Out:
# array([5., 0., 2., ..., 1., 5., 1.], shape=(12215,))

# %%
fig, ax = plt.subplots(10,4,figsize=(10,15))
for i in range(40):
    plt.subplot(10,4,i+1)
    plt.imshow(ImagensArrayTestFinal[i])
    plt.title(LabelArrayTestFinal[i])
fig.tight_layout()
plt.show()
